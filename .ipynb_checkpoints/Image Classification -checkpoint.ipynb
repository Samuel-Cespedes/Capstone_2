# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %%
def get_images(directory):
    Images = []
    Labels = []  # 0 for Building , 1 for forest, 2 for glacier, 3 for mountain, 4 for Sea , 5 for Street
    label = 0
    
    for labels in os.listdir(directory): 
        if labels == 'glacier': 
            label = 2
        elif labels == 'sea':
            label = 4
        elif labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label = 1
        elif labels == 'street':
            label = 5
        elif labels == 'mountain':
            label = 3
        
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resizing image
            Images.append(image)
            Labels.append(label)
    return shuffle(Images,Labels,random_state=817328462) #Shuffling the dataset

# %%
def get_classlabel(class_code):
    labels = {2:'glacier', 4:'sea', 0:'buildings', 1:'forest', 5:'street', 3:'mountain'}
    
    return labels[class_code]

# %%
Images, Labels = get_images('data2/seg_train/seg_train/') #Extract the training images from the folders

# %%
Images = np.array(Images) #converting the list of images to numpy array.
Labels = np.array(Labels)

# %%
Images.shape, Labels.shape
# Out:
# ((14034, 150, 150, 3), (14034,))

# %%
f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(6,activation='softmax'))

model.compile(optimizer=Optimizer.Adam(learning_rate=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.summary()
Utils.plot_model(model,to_file='model.png',show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 200)     5600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 180)     324180
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 29, 29, 180)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 180)       291780
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 140)       226940
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 100)       126100
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 21, 21, 50)        45050
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 180)               144180
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               18100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 1,187,286
# Trainable params: 1,187,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
trained = model.fit(Images,Labels,epochs=35,validation_split=0.30)
# Out:
# Epoch 1/35
# 307/307 [==============================] - 1457s 5s/step - loss: 1.5911 - accuracy: 0.3904 - val_loss: 1.1335 - val_accuracy: 0.5799
# Epoch 2/35
# 307/307 [==============================] - 1441s 5s/step - loss: 1.1765 - accuracy: 0.5337 - val_loss: 0.8876 - val_accuracy: 0.6792
# Epoch 3/35
# 307/307 [==============================] - 1438s 5s/step - loss: 1.0143 - accuracy: 0.6138 - val_loss: 0.8099 - val_accuracy: 0.6946
# Epoch 4/35
# 307/307 [==============================] - 1793s 6s/step - loss: 0.9138 - accuracy: 0.6617 - val_loss: 0.7908 - val_accuracy: 0.7060
# Epoch 5/35
# 307/307 [==============================] - 3897s 13s/step - loss: 0.8267 - accuracy: 0.7054 - val_loss: 0.6977 - val_accuracy: 0.7338
# Epoch 6/35
# 307/307 [==============================] - 4048s 13s/step - loss: 0.7396 - accuracy: 0.7339 - val_loss: 0.6270 - val_accuracy: 0.7796
# Epoch 7/35
# 307/307 [==============================] - 1419s 5s/step - loss: 0.6809 - accuracy: 0.7594 - val_loss: 0.6129 - val_accuracy: 0.7886
# Epoch 8/35
# 307/307 [==============================] - 1416s 5s/step - loss: 0.6394 - accuracy: 0.7756 - val_loss: 0.5903 - val_accuracy: 0.7896
# Epoch 9/35
# 307/307 [==============================] - 1418s 5s/step - loss: 0.5960 - accuracy: 0.7935 - val_loss: 0.5371 - val_accuracy: 0.8129
# Epoch 10/35
# 307/307 [==============================] - 1458s 5s/step - loss: 0.5778 - accuracy: 0.7986 - val_loss: 0.5583 - val_accuracy: 0.8015
# Epoch 11/35
# 307/307 [==============================] - 2056s 7s/step - loss: 0.5285 - accuracy: 0.8197 - val_loss: 0.6143 - val_accuracy: 0.7765
# Epoch 12/35
# 307/307 [==============================] - 1421s 5s/step - loss: 0.5064 - accuracy: 0.8268 - val_loss: 0.6006 - val_accuracy: 0.7917
# Epoch 13/35
# 307/307 [==============================] - 3142s 10s/step - loss: 0.4621 - accuracy: 0.8431 - val_loss: 0.5308 - val_accuracy: 0.8190
# Epoch 14/35
# 307/307 [==============================] - 4098s 13s/step - loss: 0.4275 - accuracy: 0.8543 - val_loss: 0.4890 - val_accuracy: 0.8312
# Epoch 15/35
# 307/307 [==============================] - 6900s 23s/step - loss: 0.4112 - accuracy: 0.8543 - val_loss: 0.4895 - val_accuracy: 0.8383
# Epoch 16/35
# 307/307 [==============================] - 10459s 34s/step - loss: 0.3774 - accuracy: 0.8726 - val_loss: 0.4896 - val_accuracy: 0.8402
# Epoch 17/35
# 307/307 [==============================] - 3582s 12s/step - loss: 0.3613 - accuracy: 0.8747 - val_loss: 0.4972 - val_accuracy: 0.8418
# Epoch 18/35
# 307/307 [==============================] - 4545s 15s/step - loss: 0.3115 - accuracy: 0.8942 - val_loss: 0.5155 - val_accuracy: 0.8271
# Epoch 19/35
# 307/307 [==============================] - 1497s 5s/step - loss: 0.3076 - accuracy: 0.8944 - val_loss: 0.5663 - val_accuracy: 0.8236
# Epoch 20/35
# 307/307 [==============================] - 1906s 6s/step - loss: 0.2901 - accuracy: 0.9010 - val_loss: 0.5559 - val_accuracy: 0.8219
# Epoch 21/35
# 307/307 [==============================] - 1453s 5s/step - loss: 0.2614 - accuracy: 0.9138 - val_loss: 0.5202 - val_accuracy: 0.8366
# Epoch 22/35
# 307/307 [==============================] - 4025s 13s/step - loss: 0.2332 - accuracy: 0.9220 - val_loss: 0.5838 - val_accuracy: 0.8369
# Epoch 23/35
# 307/307 [==============================] - 1443s 5s/step - loss: 0.2173 - accuracy: 0.9250 - val_loss: 0.5815 - val_accuracy: 0.8295
# Epoch 24/35
# 307/307 [==============================] - 3373s 11s/step - loss: 0.2068 - accuracy: 0.9289 - val_loss: 0.7730 - val_accuracy: 0.8148
# Epoch 25/35
# 307/307 [==============================] - 2765s 9s/step - loss: 0.1730 - accuracy: 0.9420 - val_loss: 0.6209 - val_accuracy: 0.8300
# Epoch 26/35
# 307/307 [==============================] - 1429s 5s/step - loss: 0.1791 - accuracy: 0.9392 - val_loss: 0.6479 - val_accuracy: 0.8435
# Epoch 27/35
# 307/307 [==============================] - 1441s 5s/step - loss: 0.1490 - accuracy: 0.9525 - val_loss: 0.8562 - val_accuracy: 0.8069
# Epoch 28/35
# 307/307 [==============================] - 3170s 10s/step - loss: 0.1565 - accuracy: 0.9505 - val_loss: 0.6502 - val_accuracy: 0.8376
# Epoch 29/35
# 307/307 [==============================] - 3371s 11s/step - loss: 0.1466 - accuracy: 0.9535 - val_loss: 0.7321 - val_accuracy: 0.8198
# Epoch 30/35
# 307/307 [==============================] - 4071s 13s/step - loss: 0.1045 - accuracy: 0.9657 - val_loss: 0.7684 - val_accuracy: 0.8459
# Epoch 31/35
# 307/307 [==============================] - 2144s 7s/step - loss: 0.1140 - accuracy: 0.9621 - val_loss: 0.8133 - val_accuracy: 0.8399
# Epoch 32/35
# 307/307 [==============================] - 2840s 9s/step - loss: 0.1354 - accuracy: 0.9570 - val_loss: 0.7574 - val_accuracy: 0.8357
# Epoch 33/35
# 307/307 [==============================] - 7632s 25s/step - loss: 0.0813 - accuracy: 0.9732 - val_loss: 0.7837 - val_accuracy: 0.8319
# Epoch 34/35
# 307/307 [==============================] - 4407s 14s/step - loss: 0.1043 - accuracy: 0.9679 - val_loss: 0.8438 - val_accuracy: 0.8359
# Epoch 35/35
# 307/307 [==============================] - 1418s 5s/step - loss: 0.0986 - accuracy: 0.9677 - val_loss: 0.8074 - val_accuracy: 0.8364

# %%
plot.plot(trained.history['accuracy'])
plot.plot(trained.history['val_accuracy'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %%
test_images,test_labels = get_images('data/seg_test/seg_test/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 94/94 [==============================] - 114s 1s/step - loss: 0.7519 - accuracy: 0.8420
# [0.7518999576568604, 0.8420000076293945]

# %%
pred_images,no_labels = get_images('data/seg_pred/')
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 150, 150, 3)

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(25):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(pred_images))
    pred_image = np.array([pred_images[rnd_number]])
    pred_class = get_classlabel(model.predict_classes(pred_image)[0])
    pred_prob = model.predict(pred_image).reshape(6)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            ax.set_title(pred_class)
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
        else:
            ax = plot.Subplot(fig, inner[j])
            ax.bar([0,1,2,3,4,5],pred_prob)
            fig.add_subplot(ax)


fig.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# <ipython-input-15-26ed54e093ba>:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
